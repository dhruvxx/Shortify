# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 44.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 87.4 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import AutoTokenizer, AutoModelWithLMHead

# %%
tokenizer = AutoTokenizer.from_pretrained('t5-base')
model = AutoModelWithLMHead.from_pretrained('t5-base', return_dict=True)
# Out:
# ...
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# ...

# %%
# text = "Water scarcity in India is an ongoing water crisis that affects hundreds of millions of people each year. I am fortunate enough to be in a middle-class family, and therefore, I have never had to face water scarcity issues. However, my parents made me understand that a basic amenity like water, which most of us take for granted, could be life-defining for many people. Therefore, in my sophomore year of college, I collaborated with WaterAid to create a web application called JalVaani. This application aimed for water tracking in the Debagarh district in Odisha, a state with acute water shortage problems. The application tracks whether each water source in the district had water on a given day. Villagers had access to a toll-free number where they could press either 1 or 0 to indicate water availability. This data was parsed, and the resultant graphs (over a while) helped the organisation improve the water sources in the particular village. I really loved working on this project because my work positively impacted thousands of people. It is not very frequent that work done in Computer Science can improve people's lives, and I am very thankful that I got to work on this project."

# %%
# !wget "https://datasets-server.huggingface.co/first-rows?dataset=cnn_dailymail&config=1.0.0&split=test"

# %%
# !unzip archive.zip
# Out:
# Archive:  archive.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of archive.zip or
#         archive.zip.zip, and cannot find archive.zip.ZIP, period.

# %%
import pandas as pd
import csv
# df = pd.read_csv('test.csv', header = None, delimiter=",", quoting=csv.QUOTE_NONE, encoding='utf-8')
df = pd.read_csv('test.csv')
df.head()
# Out:
#                                          id  \
# 0  92c514c913c0bdfe25341af9fd72b29db544099b
# 1  2003841c7dc0e7c5b1a248f9cd536d727f27a45a
# 2  91b7d2311527f5c2b63a65ca98d21d9c92485149
# 3  caabf9cbdf96eb1410295a673e953d304391bfbb
# 4  3da746a7d9afcaa659088c8366ef6347fe6b53ea
#
#                                              article  \
# 0  Ever noticed how plane seats appear to be gett...
# 1  A drunk teenage boy had to be rescued by secur...
# 2  Dougie Freedman is on the verge of agreeing a ...
# 3  Liverpool target Neto is also wanted by PSG an...
# 4  Bruce Jenner will break his silence in a two-h...
#
#                                           highlights
# 0  Experts question if  packed out planes are put...
# 1  Drunk teenage boy climbed into lion enclosure ...
# 2  Nottingham Forest are close to extending Dougi...
# 3  Fiorentina goalkeeper Neto has been linked wit...
# 4  Tell-all interview with the reality TV star, 6...

# %%
df = df.sample(frac=0.1)
len(df)
# Out:
# 1149

# %%
def summarize(text):
  inputs = tokenizer.encode("summarize:"+text,
                          return_tensors='pt',
                          max_length=128,
                          truncation=True)
  summary_ids = model.generate(inputs, max_length=150, min_length=80, length_penalty=5., num_beams=2)
  return tokenizer.decode(summary_ids[0])

# %%
# !pip install swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 830.9/830.9 KB 12.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 50.8 MB/s eta 0:00:00
# ...
#   Created wheel for swifter: filename=swifter-1.3.4-py3-none-any.whl size=16321 sha256=43d60123c4ed170d8e26bb6cbf41b96c5b0bfda98aabcf3431c2f27d267f317d
#   Stored in directory: /root/.cache/pip/wheels/2b/5e/f2/3931524f702ffd03309e96d35ee2fbf9c61c27377511ee8d4c
# Successfully built swifter
# ...

# %%
import swifter

# %%
df['summary'] = df['article'].swifter.apply(lambda text: summarize(text))
# Out:
# Pandas Apply:   0%|          | 0/1149 [00:00<?, ?it/s]

# %%
df.head()
# Out:
#                                              id  \
# 2956   85d5e1bded6364f8ff432df5615eca1804c59cbf
# 1758   1184e89ec8f7ee863b7de68f1d42894ad5c3ac05
# 9203   ce7a3cc9e26d0c728a82b5631fbea0dc8948d929
# 11027  088992ee453bd3acbb82baefc7f0f1be96eb6aaf
# 8356   032bd00214629a8af90f1817d1d611224bd6d3ed
#
#                                                  article  \
# 2956   Cosmopolitan editor Bronwyn McCahon says she r...
# 1758   George Osborne has refused to rule out further...
# 9203   The lawyers for a female Pennsylvania police o...
# 11027  The crew of a Turkish airlines flight are bein...
# 8356   A member of one of Australia's most notorious ...
#
#                                               highlights  \
# 2956   Belle Gibson was awarded Cosmo's Fun Fearless ...
# 1758   Chancellor paves the way for further cuts to p...
# 9203   Pennsylvania police officer Lisa Mearkle charg...
# 11027  Arda Turan was pictured in the cockpit of a Tu...
# ...

# %%
df.to_csv('summarized_text.csv')
